# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]['description']
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sao felix do xingu
# Processing Record 2 of Set 1 | souillac
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | pattoki
# Processing Record 5 of Set 1 | kruisfontein
# Processing Record 6 of Set 1 | rolim de moura
# City not found. Skipping...
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | russell
# Processing Record 9 of Set 1 | hualmay
# Processing Record 10 of Set 1 | port lincoln
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | beidao
# Processing Record 13 of Set 1 | torbay
# Processing Record 14 of Set 1 | ketchikan
# Processing Record 15 of Set 1 | pangnirtung
# Processing Record 16 of Set 1 | saldanha
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | terney
# Processing Record 20 of Set 1 | maningrida
# Processing Record 21 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | carnarvon
# Processing Record 25 of Set 1 | matamoros
# Processing Record 26 of Set 1 | rio gallegos
# Processing Record 27 of Set 1 | palauig
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | leningradskiy
# Processing Record 30 of Set 1 | college
# Processing Record 31 of Set 1 | kiama
# Processing Record 32 of Set 1 | kytmanovo
# Processing Record 33 of Set 1 | yinchuan
# Processing Record 34 of Set 1 | butaritari
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | esperance
# Processing Record 37 of Set 1 | tres arroyos
# Processing Record 38 of Set 1 | georgetown
# Processing Record 39 of Set 1 | knysna
# Processing Record 40 of Set 1 | ribeira grande
# Processing Record 41 of Set 1 | coihaique
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | shitanjing
# Processing Record 44 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 1 | bacolod
# Processing Record 46 of Set 1 | nangomba
# Processing Record 47 of Set 1 | vaitape
# Processing Record 48 of Set 1 | margate
# Processing Record 49 of Set 1 | poum
# Processing Record 50 of Set 1 | alenquer
# Processing Record 1 of Set 2 | yulara
# Processing Record 2 of Set 2 | rikitea
# Processing Record 3 of Set 2 | punta arenas
# Processing Record 4 of Set 2 | geraldton
# Processing Record 5 of Set 2 | upernavik
# Processing Record 6 of Set 2 | puerto colombia
# Processing Record 7 of Set 2 | busselton
# Processing Record 8 of Set 2 | atuona
# Processing Record 9 of Set 2 | hamilton
# Processing Record 10 of Set 2 | hilo
# Processing Record 11 of Set 2 | praia da vitoria
# Processing Record 12 of Set 2 | bandar-e lengeh
# Processing Record 13 of Set 2 | leh
# Processing Record 14 of Set 2 | zimovniki
# Processing Record 15 of Set 2 | vila do maio
# Processing Record 16 of Set 2 | berbera
# Processing Record 17 of Set 2 | xichang
# Processing Record 18 of Set 2 | beyneu
# Processing Record 19 of Set 2 | alofi
# Processing Record 20 of Set 2 | ozernovskiy
# Processing Record 21 of Set 2 | severnyy-kospashskiy
# Processing Record 22 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 24 of Set 2 | suket
# Processing Record 25 of Set 2 | new norfolk
# Processing Record 26 of Set 2 | kayes
# Processing Record 27 of Set 2 | krasnoselkup
# Processing Record 28 of Set 2 | tasiilaq
# Processing Record 29 of Set 2 | severo-kurilsk
# Processing Record 30 of Set 2 | cubuk
# Processing Record 31 of Set 2 | lavrentiya
# Processing Record 32 of Set 2 | puerto ayora
# Processing Record 33 of Set 2 | barrow
# Processing Record 34 of Set 2 | roblin
# Processing Record 35 of Set 2 | ambilobe
# Processing Record 36 of Set 2 | castro
# Processing Record 37 of Set 2 | lokot
# Processing Record 38 of Set 2 | east london
# Processing Record 39 of Set 2 | hasaki
# Processing Record 40 of Set 2 | port alfred
# Processing Record 41 of Set 2 | kutum
# Processing Record 42 of Set 2 | solnechnyy
# Processing Record 43 of Set 2 | imbituba
# Processing Record 44 of Set 2 | sao filipe
# Processing Record 45 of Set 2 | mount gambier
# Processing Record 46 of Set 2 | katsuura
# Processing Record 47 of Set 2 | nakamura
# Processing Record 48 of Set 2 | arlit
# Processing Record 49 of Set 2 | vaini
# Processing Record 50 of Set 2 | thompson
# Processing Record 1 of Set 3 | mahebourg
# Processing Record 2 of Set 3 | krasnoarmeysk
# Processing Record 3 of Set 3 | namibe
# Processing Record 4 of Set 3 | taua
# Processing Record 5 of Set 3 | anadyr
# Processing Record 6 of Set 3 | klaksvik
# Processing Record 7 of Set 3 | riyadh
# Processing Record 8 of Set 3 | la ronge
# Processing Record 9 of Set 3 | mehran
# Processing Record 10 of Set 3 | ozgon
# City not found. Skipping...
# Processing Record 11 of Set 3 | laguna
# Processing Record 12 of Set 3 | sumkino
# Processing Record 13 of Set 3 | flinders
# Processing Record 14 of Set 3 | cape town
# Processing Record 15 of Set 3 | tambilil
# Processing Record 16 of Set 3 | svetlyy
# Processing Record 17 of Set 3 | iqaluit
# Processing Record 18 of Set 3 | khatanga
# Processing Record 19 of Set 3 | kapaa
# Processing Record 20 of Set 3 | ponta do sol
# Processing Record 21 of Set 3 | tinqueux
# Processing Record 22 of Set 3 | auki
# Processing Record 23 of Set 3 | talnakh
# Processing Record 24 of Set 3 | havoysund
# Processing Record 25 of Set 3 | concordia
# Processing Record 26 of Set 3 | port elizabeth
# Processing Record 27 of Set 3 | valdivia
# Processing Record 28 of Set 3 | tabuk
# Processing Record 29 of Set 3 | ostrovnoy
# Processing Record 30 of Set 3 | dicabisagan
# Processing Record 31 of Set 3 | mar del plata
# Processing Record 32 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 3 | xiongyue
# Processing Record 34 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 3 | asau
# Processing Record 36 of Set 3 | helong
# Processing Record 37 of Set 3 | ahipara
# Processing Record 38 of Set 3 | kodiak
# Processing Record 39 of Set 3 | avarua
# Processing Record 40 of Set 3 | codrington
# Processing Record 41 of Set 3 | poykovskiy
# Processing Record 42 of Set 3 | pevek
# Processing Record 43 of Set 3 | ola
# Processing Record 44 of Set 3 | kahului
# Processing Record 45 of Set 3 | birao
# Processing Record 46 of Set 3 | fortuna
# Processing Record 47 of Set 3 | westport
# Processing Record 48 of Set 3 | parit buntar
# Processing Record 49 of Set 3 | morris
# Processing Record 50 of Set 3 | hambantota
# Processing Record 1 of Set 4 | zhanatas
# City not found. Skipping...
# Processing Record 2 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 4 | eyl
# Processing Record 4 of Set 4 | asayita
# City not found. Skipping...
# Processing Record 5 of Set 4 | altukhovo
# Processing Record 6 of Set 4 | scottsbluff
# Processing Record 7 of Set 4 | badiraguato
# Processing Record 8 of Set 4 | hailar
# Processing Record 9 of Set 4 | yumen
# Processing Record 10 of Set 4 | tilichiki
# Processing Record 11 of Set 4 | bandar
# Processing Record 12 of Set 4 | longyearbyen
# Processing Record 13 of Set 4 | victoria
# Processing Record 14 of Set 4 | yellowknife
# Processing Record 15 of Set 4 | mangrol
# Processing Record 16 of Set 4 | bambous virieux
# Processing Record 17 of Set 4 | broken hill
# Processing Record 18 of Set 4 | alice springs
# Processing Record 19 of Set 4 | lebu
# Processing Record 20 of Set 4 | hithadhoo
# Processing Record 21 of Set 4 | calama
# Processing Record 22 of Set 4 | los llanos de aridane
# Processing Record 23 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 4 | shingu
# Processing Record 25 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 4 | norman wells
# Processing Record 27 of Set 4 | coruripe
# Processing Record 28 of Set 4 | nadym
# Processing Record 29 of Set 4 | clyde river
# Processing Record 30 of Set 4 | sikasso
# Processing Record 31 of Set 4 | caravelas
# Processing Record 32 of Set 4 | simao
# Processing Record 33 of Set 4 | maun
# Processing Record 34 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 4 | tombouctou
# Processing Record 36 of Set 4 | shihezi
# Processing Record 37 of Set 4 | changji
# Processing Record 38 of Set 4 | linxia
# Processing Record 39 of Set 4 | alim
# Processing Record 40 of Set 4 | sebring
# Processing Record 41 of Set 4 | adamovka
# Processing Record 42 of Set 4 | kavieng
# Processing Record 43 of Set 4 | moate
# Processing Record 44 of Set 4 | umuarama
# Processing Record 45 of Set 4 | bengkulu
# Processing Record 46 of Set 4 | lata
# Processing Record 47 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 48 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 4 | sept-iles
# Processing Record 50 of Set 4 | shumskiy
# Processing Record 1 of Set 5 | pampa
# Processing Record 2 of Set 5 | dzerzhinsk
# Processing Record 3 of Set 5 | dingle
# Processing Record 4 of Set 5 | aripuana
# Processing Record 5 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 5 | pemba
# Processing Record 7 of Set 5 | buraydah
# Processing Record 8 of Set 5 | saint george
# Processing Record 9 of Set 5 | vila velha
# Processing Record 10 of Set 5 | ossining
# Processing Record 11 of Set 5 | galveston
# Processing Record 12 of Set 5 | kirakira
# Processing Record 13 of Set 5 | adrar
# Processing Record 14 of Set 5 | shakawe
# Processing Record 15 of Set 5 | kargil
# Processing Record 16 of Set 5 | hornepayne
# Processing Record 17 of Set 5 | russkaya polyana
# Processing Record 18 of Set 5 | atherton
# Processing Record 19 of Set 5 | jiwani
# Processing Record 20 of Set 5 | saskylakh
# Processing Record 21 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 5 | nome
# Processing Record 24 of Set 5 | quatre cocos
# Processing Record 25 of Set 5 | oyama
# Processing Record 26 of Set 5 | ahuimanu
# Processing Record 27 of Set 5 | bramsche
# Processing Record 28 of Set 5 | beringovskiy
# Processing Record 29 of Set 5 | saint-joseph
# Processing Record 30 of Set 5 | faya
# Processing Record 31 of Set 5 | manokwari
# Processing Record 32 of Set 5 | arraial do cabo
# Processing Record 33 of Set 5 | vila
# Processing Record 34 of Set 5 | letlhakane
# Processing Record 35 of Set 5 | komsomolskiy
# Processing Record 36 of Set 5 | marsh harbour
# Processing Record 37 of Set 5 | mumford
# Processing Record 38 of Set 5 | navolato
# Processing Record 39 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 5 | gigmoto
# Processing Record 41 of Set 5 | saint-philippe
# Processing Record 42 of Set 5 | cunha
# Processing Record 43 of Set 5 | skovorodino
# Processing Record 44 of Set 5 | macaboboni
# City not found. Skipping...
# Processing Record 45 of Set 5 | baculin
# Processing Record 46 of Set 5 | tiksi
# Processing Record 47 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 5 | port macquarie
# Processing Record 49 of Set 5 | carutapera
# Processing Record 50 of Set 5 | provideniya
# Processing Record 1 of Set 6 | belogradcik
# City not found. Skipping...
# Processing Record 2 of Set 6 | poso
# Processing Record 3 of Set 6 | vostok
# Processing Record 4 of Set 6 | fiumicino
# Processing Record 5 of Set 6 | fulda
# Processing Record 6 of Set 6 | kaitangata
# Processing Record 7 of Set 6 | nenjiang
# Processing Record 8 of Set 6 | nanortalik
# Processing Record 9 of Set 6 | shimoda
# Processing Record 10 of Set 6 | susangerd
# Processing Record 11 of Set 6 | doha
# Processing Record 12 of Set 6 | nikolskoye
# Processing Record 13 of Set 6 | arrecife
# Processing Record 14 of Set 6 | kendari
# Processing Record 15 of Set 6 | ulaanbaatar
# Processing Record 16 of Set 6 | hofn
# Processing Record 17 of Set 6 | chara
# Processing Record 18 of Set 6 | saint anthony
# Processing Record 19 of Set 6 | khorixas
# Processing Record 20 of Set 6 | band
# Processing Record 21 of Set 6 | gazanjyk
# Processing Record 22 of Set 6 | tomatlan
# Processing Record 23 of Set 6 | kalmunai
# Processing Record 24 of Set 6 | tiznit
# Processing Record 25 of Set 6 | lander
# Processing Record 26 of Set 6 | tsumeb
# Processing Record 27 of Set 6 | constitucion
# Processing Record 28 of Set 6 | brownsville
# Processing Record 29 of Set 6 | noumea
# Processing Record 30 of Set 6 | sur
# Processing Record 31 of Set 6 | ancud
# Processing Record 32 of Set 6 | san vicente
# Processing Record 33 of Set 6 | glendive
# Processing Record 34 of Set 6 | panama city
# Processing Record 35 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 36 of Set 6 | juneau
# Processing Record 37 of Set 6 | omagh
# Processing Record 38 of Set 6 | norrtalje
# Processing Record 39 of Set 6 | nyrob
# Processing Record 40 of Set 6 | camocim
# Processing Record 41 of Set 6 | timon
# Processing Record 42 of Set 6 | salalah
# Processing Record 43 of Set 6 | springbok
# Processing Record 44 of Set 6 | bowen
# Processing Record 45 of Set 6 | ambunti
# Processing Record 46 of Set 6 | dikson
# Processing Record 47 of Set 6 | bethel
# Processing Record 48 of Set 6 | dalvik
# Processing Record 49 of Set 6 | susaki
# Processing Record 50 of Set 6 | parabel
# Processing Record 1 of Set 7 | urumqi
# Processing Record 2 of Set 7 | bandarbeyla
# Processing Record 3 of Set 7 | urosevac
# City not found. Skipping...
# Processing Record 4 of Set 7 | baherden
# Processing Record 5 of Set 7 | bristol
# Processing Record 6 of Set 7 | ugoofaaru
# Processing Record 7 of Set 7 | jiuquan
# Processing Record 8 of Set 7 | angoche
# Processing Record 9 of Set 7 | coos bay
# Processing Record 10 of Set 7 | hay river
# Processing Record 11 of Set 7 | husavik
# Processing Record 12 of Set 7 | chuy
# Processing Record 13 of Set 7 | pemangkat
# Processing Record 14 of Set 7 | martapura
# Processing Record 15 of Set 7 | jinan
# Processing Record 16 of Set 7 | madang
# Processing Record 17 of Set 7 | batouri
# Processing Record 18 of Set 7 | tuatapere
# Processing Record 19 of Set 7 | iskateley
# Processing Record 20 of Set 7 | southbridge
# Processing Record 21 of Set 7 | vernon
# Processing Record 22 of Set 7 | prado
# Processing Record 23 of Set 7 | mbigou
# Processing Record 24 of Set 7 | lamar
# Processing Record 25 of Set 7 | narasannapeta
# Processing Record 26 of Set 7 | bridlington
# Processing Record 27 of Set 7 | vikindu
# Processing Record 28 of Set 7 | hun
# Processing Record 29 of Set 7 | bose
# Processing Record 30 of Set 7 | gobabis
# Processing Record 31 of Set 7 | maragogi
# Processing Record 32 of Set 7 | zaoyang
# Processing Record 33 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 7 | gamba
# Processing Record 35 of Set 7 | port hardy
# Processing Record 36 of Set 7 | navrongo
# Processing Record 37 of Set 7 | nehe
# Processing Record 38 of Set 7 | cidreira
# Processing Record 39 of Set 7 | bolshaya vishera
# City not found. Skipping...
# Processing Record 40 of Set 7 | aitape
# Processing Record 41 of Set 7 | mecca
# Processing Record 42 of Set 7 | nalut
# Processing Record 43 of Set 7 | vibo valentia
# Processing Record 44 of Set 7 | moosomin
# Processing Record 45 of Set 7 | pisco
# Processing Record 46 of Set 7 | presidente venceslau
# Processing Record 47 of Set 7 | tecoanapa
# Processing Record 48 of Set 7 | padang
# Processing Record 49 of Set 7 | mwinilunga
# Processing Record 50 of Set 7 | kollam
# Processing Record 1 of Set 8 | carupano
# Processing Record 2 of Set 8 | vestmannaeyjar
# Processing Record 3 of Set 8 | waitara
# Processing Record 4 of Set 8 | machaneng
# Processing Record 5 of Set 8 | chokurdakh
# Processing Record 6 of Set 8 | tautira
# Processing Record 7 of Set 8 | airai
# Processing Record 8 of Set 8 | antalaha
# Processing Record 9 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 10 of Set 8 | andros
# Processing Record 11 of Set 8 | nhulunbuy
# Processing Record 12 of Set 8 | yingcheng
# Processing Record 13 of Set 8 | la rioja
# Processing Record 14 of Set 8 | kavaratti
# Processing Record 15 of Set 8 | andreapol
# Processing Record 16 of Set 8 | campagna
# Processing Record 17 of Set 8 | lephepe
# City not found. Skipping...
# Processing Record 18 of Set 8 | rocha
# Processing Record 19 of Set 8 | ponta delgada
# Processing Record 20 of Set 8 | lensk
# Processing Record 21 of Set 8 | sedelnikovo
# City not found. Skipping...
# Processing Record 22 of Set 8 | tahoua
# Processing Record 23 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 24 of Set 8 | beba
# Processing Record 25 of Set 8 | almaznyy
# Processing Record 26 of Set 8 | dwarka
# Processing Record 27 of Set 8 | raga
# Processing Record 28 of Set 8 | kupang
# Processing Record 29 of Set 8 | olafsvik
# Processing Record 30 of Set 8 | yenagoa
# Processing Record 31 of Set 8 | atotonilco el grande
# Processing Record 32 of Set 8 | hailun
# Processing Record 33 of Set 8 | makakilo city
# Processing Record 34 of Set 8 | langham
# Processing Record 35 of Set 8 | kneza
# City not found. Skipping...
# Processing Record 36 of Set 8 | salamanca
# Processing Record 37 of Set 8 | nagorsk
# Processing Record 38 of Set 8 | bangangte
# Processing Record 39 of Set 8 | bairiki
# Processing Record 40 of Set 8 | slave lake
# Processing Record 41 of Set 8 | inawashiro
# Processing Record 42 of Set 8 | kaa-khem
# Processing Record 43 of Set 8 | boende
# Processing Record 44 of Set 8 | santa rosa
# Processing Record 45 of Set 8 | nuuk
# Processing Record 46 of Set 8 | san cristobal
# Processing Record 47 of Set 8 | rawson
# Processing Record 48 of Set 8 | zyryanka
# Processing Record 49 of Set 8 | suhbaatar
# Processing Record 50 of Set 8 | nouakchott
# Processing Record 1 of Set 9 | salinas
# Processing Record 2 of Set 9 | karasjok
# Processing Record 3 of Set 9 | lorengau
# Processing Record 4 of Set 9 | baruun-urt
# Processing Record 5 of Set 9 | amarillo
# Processing Record 6 of Set 9 | shadegan
# Processing Record 7 of Set 9 | guamuchil
# Processing Record 8 of Set 9 | shellbrook
# Processing Record 9 of Set 9 | evanston
# Processing Record 10 of Set 9 | eureka
# Processing Record 11 of Set 9 | resistencia
# Processing Record 12 of Set 9 | yashan
# Processing Record 13 of Set 9 | acapulco
# Processing Record 14 of Set 9 | omaruru
# Processing Record 15 of Set 9 | mrakovo
# Processing Record 16 of Set 9 | mount isa
# Processing Record 17 of Set 9 | chake chake
# Processing Record 18 of Set 9 | mulanje
# Processing Record 19 of Set 9 | olinda
# Processing Record 20 of Set 9 | terrace
# Processing Record 21 of Set 9 | salym
# Processing Record 22 of Set 9 | lagoa
# Processing Record 23 of Set 9 | harper
# Processing Record 24 of Set 9 | quesnel
# Processing Record 25 of Set 9 | misratah
# Processing Record 26 of Set 9 | bilibino
# Processing Record 27 of Set 9 | batemans bay
# Processing Record 28 of Set 9 | winnemucca
# Processing Record 29 of Set 9 | ilam
# Processing Record 30 of Set 9 | paamiut
# Processing Record 31 of Set 9 | benevento
# Processing Record 32 of Set 9 | potenza
# Processing Record 33 of Set 9 | port blair
# Processing Record 34 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 35 of Set 9 | jiayuguan
# Processing Record 36 of Set 9 | kashi
# Processing Record 37 of Set 9 | praia
# Processing Record 38 of Set 9 | biggar
# Processing Record 39 of Set 9 | marzuq
# Processing Record 40 of Set 9 | aklavik
# Processing Record 41 of Set 9 | high rock
# Processing Record 42 of Set 9 | san ignacio
# Processing Record 43 of Set 9 | skjervoy
# Processing Record 44 of Set 9 | areosa
# Processing Record 45 of Set 9 | fairbanks
# Processing Record 46 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 9 | brae
# Processing Record 48 of Set 9 | qaqortoq
# Processing Record 49 of Set 9 | maniitsoq
# Processing Record 50 of Set 9 | peniche
# Processing Record 1 of Set 10 | vila franca do campo
# Processing Record 2 of Set 10 | ayolas
# Processing Record 3 of Set 10 | cascais
# Processing Record 4 of Set 10 | guerrero negro
# Processing Record 5 of Set 10 | naze
# Processing Record 6 of Set 10 | aksum
# Processing Record 7 of Set 10 | ode
# Processing Record 8 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 9 of Set 10 | hovd
# Processing Record 10 of Set 10 | chapais
# Processing Record 11 of Set 10 | urucara
# Processing Record 12 of Set 10 | bac lieu
# Processing Record 13 of Set 10 | ibra
# Processing Record 14 of Set 10 | sarlat-la-caneda
# Processing Record 15 of Set 10 | felanitx
# Processing Record 16 of Set 10 | kapustin yar
# Processing Record 17 of Set 10 | buchanan
# Processing Record 18 of Set 10 | touros
# Processing Record 19 of Set 10 | myitkyina
# Processing Record 20 of Set 10 | grindavik
# Processing Record 21 of Set 10 | cherskiy
# Processing Record 22 of Set 10 | srednekolymsk
# Processing Record 23 of Set 10 | faanui
# Processing Record 24 of Set 10 | gravdal
# Processing Record 25 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 26 of Set 10 | saint quentin
# City not found. Skipping...
# Processing Record 27 of Set 10 | abu samrah
# Processing Record 28 of Set 10 | qui nhon
# Processing Record 29 of Set 10 | jardim
# Processing Record 30 of Set 10 | srebrenica
# Processing Record 31 of Set 10 | aksu
# Processing Record 32 of Set 10 | rijeka
# Processing Record 33 of Set 10 | bundaberg
# Processing Record 34 of Set 10 | uttaradit
# Processing Record 35 of Set 10 | muriwai beach
# Processing Record 36 of Set 10 | grand-lahou
# Processing Record 37 of Set 10 | santa vitoria do palmar
# Processing Record 38 of Set 10 | muros
# Processing Record 39 of Set 10 | narsaq
# Processing Record 40 of Set 10 | imeni zhelyabova
# Processing Record 41 of Set 10 | kamaishi
# Processing Record 42 of Set 10 | rio grande
# Processing Record 43 of Set 10 | sungaipenuh
# Processing Record 44 of Set 10 | coahuayana
# Processing Record 45 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 10 | san roque
# Processing Record 47 of Set 10 | karpogory
# Processing Record 48 of Set 10 | tevaitoa
# Processing Record 49 of Set 10 | burlington
# Processing Record 50 of Set 10 | fort nelson
# Processing Record 1 of Set 11 | makung
# City not found. Skipping...
# Processing Record 2 of Set 11 | milkovo
# Processing Record 3 of Set 11 | agadir
# Processing Record 4 of Set 11 | markova
# Processing Record 5 of Set 11 | cabo san lucas
# Processing Record 6 of Set 11 | sakaraha
# Processing Record 7 of Set 11 | aksha
# Processing Record 8 of Set 11 | wadena
# Processing Record 9 of Set 11 | buala
# Processing Record 10 of Set 11 | punto fijo
# Processing Record 11 of Set 11 | at-bashi
# Processing Record 12 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 11 | kudahuvadhoo
# Processing Record 14 of Set 11 | baijiantan
# Processing Record 15 of Set 11 | sarkand
# Processing Record 16 of Set 11 | vieques
# Processing Record 17 of Set 11 | novobureyskiy
# Processing Record 18 of Set 11 | karabulak
# Processing Record 19 of Set 11 | bathsheba
# Processing Record 20 of Set 11 | abu dhabi
# Processing Record 21 of Set 11 | port augusta
# Processing Record 22 of Set 11 | xuddur
# Processing Record 23 of Set 11 | vadakku valliyur
# Processing Record 24 of Set 11 | mogadishu
# Processing Record 25 of Set 11 | taksimo
# Processing Record 26 of Set 11 | turbat
# Processing Record 27 of Set 11 | asfi
# Processing Record 28 of Set 11 | superior
# Processing Record 29 of Set 11 | saint-augustin
# Processing Record 30 of Set 11 | ust-omchug
# Processing Record 31 of Set 11 | plastun
# Processing Record 32 of Set 11 | gazli
# Processing Record 33 of Set 11 | fare
# Processing Record 34 of Set 11 | isangel
# Processing Record 35 of Set 11 | puerto lopez
# Processing Record 36 of Set 11 | el cope
# Processing Record 37 of Set 11 | mahibadhoo
# Processing Record 38 of Set 11 | kuah
# Processing Record 39 of Set 11 | cherkasskoye
# Processing Record 40 of Set 11 | kijang
# Processing Record 41 of Set 11 | avera
# Processing Record 42 of Set 11 | khaniotis
# Processing Record 43 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 11 | levokumskoye
# Processing Record 45 of Set 11 | fomboni
# Processing Record 46 of Set 11 | iracoubo
# Processing Record 47 of Set 11 | weligama
# Processing Record 48 of Set 11 | haines junction
# Processing Record 49 of Set 11 | abha
# Processing Record 50 of Set 11 | general pico
# Processing Record 1 of Set 12 | ilulissat
# Processing Record 2 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 3 of Set 12 | guanica
# Processing Record 4 of Set 12 | copiapo
# Processing Record 5 of Set 12 | tabuleiro do norte
# Processing Record 6 of Set 12 | tamworth
# Processing Record 7 of Set 12 | atar
# Processing Record 8 of Set 12 | aswan
# Processing Record 9 of Set 12 | progreso
# Processing Record 10 of Set 12 | jieshi
# Processing Record 11 of Set 12 | chernyshevskiy
# Processing Record 12 of Set 12 | nautla
# Processing Record 13 of Set 12 | coquimbo
# Processing Record 14 of Set 12 | luderitz
# Processing Record 15 of Set 12 | portland
# Processing Record 16 of Set 12 | kukuna
# Processing Record 17 of Set 12 | pacific grove
# Processing Record 18 of Set 12 | san patricio
# Processing Record 19 of Set 12 | cockburn town
# Processing Record 20 of Set 12 | cap malheureux
# Processing Record 21 of Set 12 | wajima
# Processing Record 22 of Set 12 | mae hong son
# Processing Record 23 of Set 12 | toamasina
# Processing Record 24 of Set 12 | bereda
# Processing Record 25 of Set 12 | tarauaca
# Processing Record 26 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 27 of Set 12 | merauke
# Processing Record 28 of Set 12 | awbari
# Processing Record 29 of Set 12 | qianan
# Processing Record 30 of Set 12 | vestmanna
# Processing Record 31 of Set 12 | itoman
# Processing Record 32 of Set 12 | thinadhoo
# Processing Record 33 of Set 12 | cherat
# Processing Record 34 of Set 12 | ust-kut
# Processing Record 35 of Set 12 | yerbogachen
# Processing Record 36 of Set 12 | qarqin
# Processing Record 37 of Set 12 | nicoya
# Processing Record 38 of Set 12 | pawa
# Processing Record 39 of Set 12 | iwanai
# Processing Record 40 of Set 12 | tucupita
# Processing Record 41 of Set 12 | safaqis
# City not found. Skipping...
# Processing Record 42 of Set 12 | lompoc
# Processing Record 43 of Set 12 | innisfail
# Processing Record 44 of Set 12 | sobolevo
# Processing Record 45 of Set 12 | grafton
# Processing Record 46 of Set 12 | charters towers
# Processing Record 47 of Set 12 | whittlesea
# Processing Record 48 of Set 12 | sciacca
# Processing Record 49 of Set 12 | nainpur
# Processing Record 50 of Set 12 | kieta
# Processing Record 1 of Set 13 | vincennes
# Processing Record 2 of Set 13 | mana
# Processing Record 3 of Set 13 | jonuta
# Processing Record 4 of Set 13 | iroquois falls
# Processing Record 5 of Set 13 | hellvik
# Processing Record 6 of Set 13 | meiganga
# Processing Record 7 of Set 13 | mahon
# Processing Record 8 of Set 13 | rio cuarto
# Processing Record 9 of Set 13 | safwah
# City not found. Skipping...
# Processing Record 10 of Set 13 | jose de freitas
# Processing Record 11 of Set 13 | tuktoyaktuk
# Processing Record 12 of Set 13 | pisz
# Processing Record 13 of Set 13 | kuhestan
# City not found. Skipping...
# Processing Record 14 of Set 13 | kiunga
# Processing Record 15 of Set 13 | bubaque
# Processing Record 16 of Set 13 | mantua
# Processing Record 17 of Set 13 | siemiatycze
# Processing Record 18 of Set 13 | ferme-neuve
# Processing Record 19 of Set 13 | andenes
# Processing Record 20 of Set 13 | kachug
# Processing Record 21 of Set 13 | nantucket
# Processing Record 22 of Set 13 | koumac
# Processing Record 23 of Set 13 | madison heights
# Processing Record 24 of Set 13 | rock falls
# Processing Record 25 of Set 13 | nuevo progreso
# Processing Record 26 of Set 13 | udachnyy
# Processing Record 27 of Set 13 | sibiti
# Processing Record 28 of Set 13 | kilmallock
# Processing Record 29 of Set 13 | port hedland
# Processing Record 30 of Set 13 | shenjiamen
# Processing Record 31 of Set 13 | marquette
# Processing Record 32 of Set 13 | kamiiso
# Processing Record 33 of Set 13 | saint-pierre
# Processing Record 34 of Set 13 | burton
# Processing Record 35 of Set 13 | vanimo
# Processing Record 36 of Set 13 | marsabit
# Processing Record 37 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 38 of Set 13 | kaseda
# Processing Record 39 of Set 13 | korla
# Processing Record 40 of Set 13 | sao joao da barra
# Processing Record 41 of Set 13 | verkh-usugli
# Processing Record 42 of Set 13 | pangai
# Processing Record 43 of Set 13 | puerto madero
# Processing Record 44 of Set 13 | medzilaborce
# Processing Record 45 of Set 13 | plettenberg bay
# Processing Record 46 of Set 13 | polunochnoye
# Processing Record 47 of Set 13 | samarai
# Processing Record 48 of Set 13 | banting
# Processing Record 49 of Set 13 | tabou
# Processing Record 50 of Set 13 | majene
# Processing Record 1 of Set 14 | yeppoon
# Processing Record 2 of Set 14 | marawi
# Processing Record 3 of Set 14 | penzance
# Processing Record 4 of Set 14 | nevel
# Processing Record 5 of Set 14 | cayenne
# Processing Record 6 of Set 14 | rudnyy
# Processing Record 7 of Set 14 | plast
# Processing Record 8 of Set 14 | karratha
# Processing Record 9 of Set 14 | sechura
# Processing Record 10 of Set 14 | qianguo
# Processing Record 11 of Set 14 | pirenopolis
# Processing Record 12 of Set 14 | omsukchan
# Processing Record 13 of Set 14 | camacha
# Processing Record 14 of Set 14 | kuching
# Processing Record 15 of Set 14 | comodoro rivadavia
# Processing Record 16 of Set 14 | berlevag
# Processing Record 17 of Set 14 | sibu
# Processing Record 18 of Set 14 | mangochi
# Processing Record 19 of Set 14 | melendugno
# Processing Record 20 of Set 14 | chunhuhub
# Processing Record 21 of Set 14 | marshall
# Processing Record 22 of Set 14 | barra patuca
# Processing Record 23 of Set 14 | tual
# Processing Record 24 of Set 14 | teluk nibung
# Processing Record 25 of Set 14 | leshukonskoye
# Processing Record 26 of Set 14 | nelson bay
# Processing Record 27 of Set 14 | kamarion
# Processing Record 28 of Set 14 | mocuba
# Processing Record 29 of Set 14 | hobyo
# Processing Record 30 of Set 14 | roma
# Processing Record 31 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 32 of Set 14 | aykhal
# Processing Record 33 of Set 14 | kirensk
# Processing Record 34 of Set 14 | sydney mines
# Processing Record 35 of Set 14 | boa vista
# Processing Record 36 of Set 14 | nakapiripirit
# Processing Record 37 of Set 14 | canelones
# Processing Record 38 of Set 14 | monte alegre de minas
# Processing Record 39 of Set 14 | storsteinnes
# Processing Record 40 of Set 14 | blagoyevo
# Processing Record 41 of Set 14 | the pas
# Processing Record 42 of Set 14 | quthing
# Processing Record 43 of Set 14 | augusto correa
# Processing Record 44 of Set 14 | meulaboh
# Processing Record 45 of Set 14 | kara
# Processing Record 46 of Set 14 | macusani
# Processing Record 47 of Set 14 | baghdad
# Processing Record 48 of Set 14 | arman
# Processing Record 49 of Set 14 | nouadhibou
# Processing Record 50 of Set 14 | samfya
# Processing Record 1 of Set 15 | homer
# Processing Record 2 of Set 15 | tortoli
# Processing Record 3 of Set 15 | talavera
# Processing Record 4 of Set 15 | yar-sale
# Processing Record 5 of Set 15 | huarmey
# Processing Record 6 of Set 15 | la palma
# Processing Record 7 of Set 15 | coachella
# Processing Record 8 of Set 15 | belomorsk
# Processing Record 9 of Set 15 | sioux lookout
# Processing Record 10 of Set 15 | khani
# Processing Record 11 of Set 15 | mankovo-kalitvenskoye
# City not found. Skipping...
# Processing Record 12 of Set 15 | zhangzhou
# Processing Record 13 of Set 15 | florence
# Processing Record 14 of Set 15 | waling
# Processing Record 15 of Set 15 | baracoa
# Processing Record 16 of Set 15 | jabinyanah
# Processing Record 17 of Set 15 | hendersonville
# Processing Record 18 of Set 15 | miraflores
# Processing Record 19 of Set 15 | ambon
# Processing Record 20 of Set 15 | cairns
# Processing Record 21 of Set 15 | nagato
# Processing Record 22 of Set 15 | anchorage
# Processing Record 23 of Set 15 | kapit
# Processing Record 24 of Set 15 | bredene
# Processing Record 25 of Set 15 | bani
# Processing Record 26 of Set 15 | pietrari
# Processing Record 27 of Set 15 | tulum
# Processing Record 28 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 29 of Set 15 | tampilisan
# Processing Record 30 of Set 15 | kloulklubed
# Processing Record 31 of Set 15 | sarangani
# Processing Record 32 of Set 15 | borisoglebskiy
# Processing Record 33 of Set 15 | butia
# Processing Record 34 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 35 of Set 15 | ambagarh chauki
# Processing Record 36 of Set 15 | morant bay
# Processing Record 37 of Set 15 | kiprinos
# City not found. Skipping...
# Processing Record 38 of Set 15 | micheweni
# Processing Record 39 of Set 15 | sitka
# Processing Record 40 of Set 15 | balsta
# Processing Record 41 of Set 15 | tucuman
# Processing Record 42 of Set 15 | xining
# Processing Record 43 of Set 15 | sainte-marie
# Processing Record 44 of Set 15 | yomitan
# City not found. Skipping...
# Processing Record 45 of Set 15 | san matias
# Processing Record 46 of Set 15 | mabaruma
# Processing Record 47 of Set 15 | kitimat
# Processing Record 48 of Set 15 | caucaia
# Processing Record 49 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 50 of Set 15 | mercedes
# Processing Record 1 of Set 16 | kindu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Sao Felix Do Xingu  -6.6447  -51.9950     84.79        41          81
# 1            Souillac -20.5167   57.5167     73.78        78          40
# 2              Albany  42.6001  -73.9662     58.57        90         100
# 3             Pattoki  31.0167   73.8500     98.47         8           4
# 4        Kruisfontein -34.0033   24.7314     54.88        90         100
# 5             Mataura -46.1927  168.8643     41.49        94          72
# 6             Russell  32.3502  -85.1999     88.92        62          20
# 7             Hualmay -11.0964  -77.6139     70.66        74          49
# 8        Port Lincoln -34.7333  135.8667     57.90        62           1
# 9              Hobart -42.8794  147.3294     45.27        83           6
#
#    Wind Speed Country                 Date Current Description
# 0        1.68      BR  2022-05-19 17:48:14       broken clouds
# 1        9.22      MU  2022-05-19 17:47:17    scattered clouds
# 2        1.01      US  2022-05-19 17:43:55     overcast clouds
# 3        1.23      PK  2022-05-19 17:48:15           clear sky
# 4        9.89      ZA  2022-05-19 17:48:15       moderate rain
# 5        7.54      NZ  2022-05-19 17:48:15          light rain
# 6        8.05      US  2022-05-19 17:45:12          few clouds
# 7       10.63      PE  2022-05-19 17:48:16    scattered clouds
# 8       15.23      AU  2022-05-19 17:48:16           clear sky
# 9        5.75      AU  2022-05-19 17:48:16           clear sky

# %%
new_column_order = ["City", "Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0  Sao Felix Do Xingu      BR  -6.6447  -51.9950     84.79        41
# 1            Souillac      MU -20.5167   57.5167     73.78        78
# 2              Albany      US  42.6001  -73.9662     58.57        90
# 3             Pattoki      PK  31.0167   73.8500     98.47         8
# 4        Kruisfontein      ZA -34.0033   24.7314     54.88        90
# 5             Mataura      NZ -46.1927  168.8643     41.49        94
# 6             Russell      US  32.3502  -85.1999     88.92        62
# 7             Hualmay      PE -11.0964  -77.6139     70.66        74
# 8        Port Lincoln      AU -34.7333  135.8667     57.90        62
# 9              Hobart      AU -42.8794  147.3294     45.27        83
#
#    Cloudiness  Wind Speed Current Description
# 0          81        1.68       broken clouds
# 1          40        9.22    scattered clouds
# 2         100        1.01     overcast clouds
# 3           4        1.23           clear sky
# 4         100        9.89       moderate rain
# 5          72        7.54          light rain
# 6          20        8.05          few clouds
# 7          49       10.63    scattered clouds
# 8           1       15.23           clear sky
# 9           6        5.75           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
